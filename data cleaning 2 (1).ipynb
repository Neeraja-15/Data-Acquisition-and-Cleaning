# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('student_performance_dataset.csv')
print(df)
# Out:
#     Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  \
# 0         S147    Male                    31        68.267841
# 1         S136    Male                    16        78.222927
# 2         S209  Female                    21        87.525096
# 3         S458  Female                    27        92.076483
# 4         S078  Female                    37        98.655517
# ..         ...     ...                   ...              ...
# 703       S492    Male                    14        84.658761
# 704       S301    Male                    35        60.278990
# 705       S473    Male                    25        98.384969
# 706       S307  Female                    21        96.148012
# 707       S046  Female                    22        80.404392
#
#      Past_Exam_Scores Parental_Education_Level Internet_Access_at_Home  \
# 0                  86              High School                     Yes
# 1                  73                      PhD                      No
# ...

# %%
print(df.head())  # Displays the first 5 rows
print(df.tail())  # Displays the last 5 rows
# Out:
#   Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0       S147    Male                    31        68.267841                86
# 1       S136    Male                    16        78.222927                73
# 2       S209  Female                    21        87.525096                74
# 3       S458  Female                    27        92.076483                99
# 4       S078  Female                    37        98.655517                63
#
#   Parental_Education_Level Internet_Access_at_Home Extracurricular_Activities  \
# 0              High School                     Yes                        Yes
# 1                      PhD                      No                         No
# 2                      PhD                     Yes                         No
# 3                Bachelors                      No                         No
# 4                  Masters                      No                        Yes
#
# ...

# %%
df.shape
# Out:
# (708, 10)

# %%
df.info
# Out:
# <bound method DataFrame.info of     Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  \
# 0         S147    Male                    31        68.267841
# 1         S136    Male                    16        78.222927
# 2         S209  Female                    21        87.525096
# 3         S458  Female                    27        92.076483
# 4         S078  Female                    37        98.655517
# ..         ...     ...                   ...              ...
# 703       S492    Male                    14        84.658761
# 704       S301    Male                    35        60.278990
# 705       S473    Male                    25        98.384969
# 706       S307  Female                    21        96.148012
# 707       S046  Female                    22        80.404392
#
#      Past_Exam_Scores Parental_Education_Level Internet_Access_at_Home  \
# 0                  86              High School                     Yes
# ...

# %%
df.columns #columns name
# Out:
# Index(['Student_ID', 'Gender', 'Study_Hours_per_Week', 'Attendance_Rate',
#        'Past_Exam_Scores', 'Parental_Education_Level',
#        'Internet_Access_at_Home', 'Extracurricular_Activities',
#        'Final_Exam_Score', 'Pass_Fail'],
#       dtype='object')

# %%
df.describe()   #Statistics for numerical Columns
# Out:
#        Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# count            708.000000       708.000000        708.000000
# mean              26.132768        78.107722         77.871469
# std                8.877727        13.802802         14.402739
# min               10.000000        50.116970         50.000000
# 25%               19.000000        67.550094         65.000000
# 50%               27.000000        79.363046         79.000000
# 75%               34.000000        89.504232         91.000000
# max               39.000000        99.967675        100.000000
#
#        Final_Exam_Score
# count        708.000000
# mean          58.771186
# std            6.705877
# min           50.000000
# 25%           52.000000
# 50%           59.500000
# 75%           64.000000
# max           77.000000

# %%
df.sample(5)
# Out:
#     Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  \
# 657       S443    Male                    25        88.549296
# 647       S235  Female                    11        84.685880
# 210       S016    Male                    24        86.306042
# 68        S089  Female                    15        56.437420
# 458       S468    Male                    10        79.914303
#
#      Past_Exam_Scores Parental_Education_Level Internet_Access_at_Home  \
# 657                83                      PhD                      No
# 647                88                Bachelors                      No
# 210                91              High School                     Yes
# 68                 58                Bachelors                     Yes
# 458                69                Bachelors                     Yes
#
#     Extracurricular_Activities  Final_Exam_Score Pass_Fail
# 657                         No                56      Fail
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                    0
# Gender                        0
# Study_Hours_per_Week          0
# Attendance_Rate               0
# Past_Exam_Scores              0
# Parental_Education_Level      0
# Internet_Access_at_Home       0
# Extracurricular_Activities    0
# Final_Exam_Score              0
# Pass_Fail                     0
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.iloc[5]
# Out:
# Student_ID                         S417
# Gender                             Male
# Study_Hours_per_Week                 30
# Attendance_Rate               84.159193
# Past_Exam_Scores                     77
# Parental_Education_Level        Masters
# Internet_Access_at_Home             Yes
# Extracurricular_Activities           No
# Final_Exam_Score                     61
# Pass_Fail                          Pass
# Name: 5, dtype: object

# %%
df['Gender'].head()
# Out:
# 0      Male
# 1      Male
# 2    Female
# 3    Female
# 4    Female
# Name: Gender, dtype: object

# %%
df.duplicated().sum()
# Out:
# 208

# %%
df[df.duplicated()]
# Out:
#     Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  \
# 20        S458  Female                    27        92.076483
# 42        S097  Female                    29        68.864298
# 49        S207  Female                    20        89.075724
# 64        S380    Male                    39        81.662039
# 90        S368  Female                    15        77.836079
# ..         ...     ...                   ...              ...
# 692       S307  Female                    21        96.148012
# 695       S198  Female                    33        87.298726
# 697       S183  Female                    35        68.461524
# 704       S301    Male                    35        60.278990
# 706       S307  Female                    21        96.148012
#
#      Past_Exam_Scores Parental_Education_Level Internet_Access_at_Home  \
# 20                 99                Bachelors                      No
# 42                 92              High School                      No
# ...

# %%
# Listwise deletion: Drop rows where any data is mising
df = pd.read_csv('student_performance_dataset.csv')
df_listwise_deleted = df.dropna()
df_listwise_deleted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Listwise deletion: Drop rows where any data is mising
# ----> 2 df = pd.read_csv('student_performance_dataset.csv')
#       3 df_listwise_deleted = df.dropna()
#       4 df_listwise_deleted
#
# NameError: name 'pd' is not defined
